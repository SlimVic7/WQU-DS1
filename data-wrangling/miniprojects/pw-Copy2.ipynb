# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
def describe(data, key):
    N = len(scripts)
    total = sum([script[key] for script in scripts])
    avg = total / N
    var = sum([(script[key] - avg)** 2 for script in scripts]) / N - 1
    s = var ** 0.5
    
    vals = sorted([script[key] for script in scripts])
    q25 = vals[N // 4]
    med = vals[N // 2]
    q75 = vals[-N // 4]

    return (total, avg, s, q25, med, q75)

# %%
summary = [('items', describe(scripts, 'items')),
           ('quantity', describe(scripts, 'quantity')),
           ('nic', describe(scripts, 'nic')),
           ('act_cost', describe(scripts, 'act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = {script['bnf_name'] for script in scripts}
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    bnf_name = script['bnf_name']
    groups[bnf_name].append(script)

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
items_by_bnf_name = []

for bnf_name, scripts_ in groups.items():
    total = sum([script['items'] for script in scripts_])
    items_by_bnf_name.append((bnf_name, total))

# %%
items_by_bnf_name
# Out:
# [('Dorzolamide/Timolol_Eye Dps 2%/0.5%', 1592),
#  ('Co-Trimoxazole_Oral Susp 40/200mg/5mlS/F', 43),
#  ('Glycerol_Suppos Child (2g)', 42),
#  ('Progynova_Tab 1mg', 28),
#  ('Great Bear_GB2 Night Drain Bag 2L', 2),
#  ('Concerta_XL Tab 36mg', 479),
#  ('Equasym XL_Cap 30mg', 305),
#  ('Ferr Fumar_Oral Soln 140mg/5ml', 191),
#  ('Denosumab_Inj 70mg/ml 1.7ml Vl', 21),
#  ('MCTprocal_Pdr Sach 16g', 2),
#  ('Nicotine_Inhalator + Inh Cart 15mg', 144),
#  ('Propranolol HCl_Oral Soln 40mg/5ml S/F', 7),
#  ('Azelaic Acid_Crm 20%', 91),
#  ('Janumet_Tab 50mg/1g', 41),
#  ('Docusate Sod_Oral Soln 12.5mg/5ml S/F', 6),
#  ('Fostair_Inh 100mcg/6mcg (120D) CFF', 11152),
#  ('AquaForm H/Gel 8g Wound Dress Ster', 7),
#  ('Respond_OstoMart OstoSeal Prote Pdr', 5),
#  ('Zemtard 120 XL_Cap 120mg', 32),
#  ('Picato_Gel 500mcg/g', 2),
#  ('Easyhaler_Budesonide 100mcg (200 D)', 36),
#  ('Etonogestrel_Implant 68mg', 77),
#  ('Logynon_Tab', 80),
#  ('Mezavant XL_Tab G/R 1.2g', 372),
#  ('Ranolazine_Tab 375mg M/R', 728),
#  ('Buscopan_Inj 20mg/ml 1ml Amp', 6),
#  ('K-Band 7cm x 4m Ktd Polyam & Cellulose C', 2),
#  ('Minoxidil_Tab 5mg', 12),
#  ('Femodene_Tab', 133),
#  ('Acrivastine_Cap 8mg', 70),
#  ('Champix_4Wk Tt Init Pack (Tab 0.5mg/1mg)', 10),
#  ('Montelukast_Tab 10mg', 8622),
#  ('Fentanyl_Transdermal Patch 50mcg/hr', 136),
#  ('Zolmitriptan_Nsl Spy 5mg/0.1ml Ud', 88),
#  ('iMEDicare Ultimate (Surefit) Maint Set C', 8),
#  ('Alprostadil_Inj 20mcg Vl + Dil', 2),
#  ('GlucoRx FinePoint Ultra Needles Pen Inj', 235),
#  ('Dipipanone HCl/Cyclizine HCl_Tab 10/30mg', 2),
#  ('Ranolazine_Tab 500mg M/R', 368),
#  ('Brimonidine Tart_Eye Dps 0.2%', 1093),
#  ('Dansac_Nova Colo Bag Opqe S/H 20-60mm', 13),
#  ('Tegaderm + Pad 5cm x 7cm VP Adh Film Dre', 17),
#  ('Zoladex LA_Implant 10.8mg SafeSystem Pfs', 290),
#  ('Haloperidol_Tab 1.5mg', 335),
#  ('Lymecycline_Cap 408mg', 3791),
#  ('Liothyronine Sod_Tab 20mcg', 114),
#  ('Macrogol_Co Oral Pdr Sach H/Strgh6.9gS/F', 43),
#  ('Calcipotriol/Betameth_Gel 0.005%/0.05%', 650),
#  ('Enoxaparin_Inj 150mg/ml 1ml Pfs', 13),
#  ('Vesicare_Tab 10mg', 52),
#  ('Tritamyl_G/F Bread Mix Wte', 2),
#  ('GlucoMen Visio (Reagent)_Strips', 2),
#  ('Hypromellose_Eye Dps 0.32% 0.5ml Ud', 10),
#  ('Fluorouracil_Crm 5%', 110),
#  ('Vanilla Blush_Ladies Brief Mixed Size 6-', 2),
#  ('Doublebase_Emollient Bath Add', 133),
#  ('Clotrimazole_Soln 1%', 38),
#  ('Glutafin_G/F W/F Tagliatelle Nest', 7),
#  ('TriCare Needles Pen Inj Screw On 8mm/31', 12),
#  ('Tubifast 2-Way Stch 7.5cm x 5m (Blue) St', 78),
#  ('OpSite Plus 6.5cm x 5cm VP Adh Film Dres', 5),
#  ('Adipine MR 20_Tab 20mg', 164),
#  ('Diclofenac Sod_Gel 2.32%', 731),
#  ('Flomaxtra XL_Tab 400mcg P/R', 10),
#  ('Glucoject Needles Pen Inj Screw On 4mm/3', 21),
#  ('Zuclopenth Decan_Inj 500mg/ml 1ml Amp', 9),
#  ('Salbutamol_Inh Soln 5mg/2.5ml Ud', 910),
#  ('Fluorigard Daily_Dental Rinse 0.05% A/F', 6),
#  ('Jobst Elvarex Soft For L/Extrem Class 1', 10),
#  ('Coal Tar_Ext Shampoo 5%', 49),
#  ('Plendil_Tab 10mg', 9),
#  ('OpSite Post-Op 10cm x 12cm VP Adh Film D', 2),
#  ('Byetta_Inj 10mcg/0.04ml 2.4ml Pfs (60D)', 7),
#  ('Aviva (Reagent)_Strips', 3203),
#  ('Imiquimod_Crm 5% Sach 250mg', 17),
#  ('Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml', 1092),
#  ('Nicardipine HCl_Cap 30mg', 2),
#  ('Paramax_Pdr Sach S/F', 7),
#  ('Tenormin L.S._Tab 50mg', 15),
#  ('Nicorette_Cools Loz 2mg', 4),
#  ('Mst Continus_Tab 30mg', 855),
#  ('Pimozide_Tab 4mg', 5),
#  ('Diprobase_Oint', 784),
#  ('Viridal Duo_Cont Pack Inj 20mcg Cart', 4),
#  ('Fortini_Multi Fibre Liq (Unflav)', 2),
#  ('Mirena_Intra-Uterine System', 205),
#  ('Maxolon_Tab 10mg', 2),
#  ('Sod Cromoglicate_Eye Dps 2% 0.3ml Ud P/F', 7),
#  ('Diclofenac Sod_Tab E/C 50mg', 1855),
#  ('Asacol_MR Tab E/C 400mg', 694),
#  ('Mesalazine_Enem 2g In 59ml', 4),
#  ('Lansoprazole_Orodisper Tab 15mg', 1244),
#  ('Lacosamide_Tab 150mg', 11),
#  ('Aquacel Extra 10cm x 10cm Wound Dress Pr', 101),
#  ('Diclofenac Sod_Suppos 100mg', 99),
#  ('kliniderm Foam Slc Border 7.5cm x 7.5cm', 4),
#  ('Trandate_Tab 100mg', 14),
#  ('Sterimar Hypertonic Nsl Spy 50ml', 73),
#  ('Penicillamine_Tab 250mg', 3),
#  ('Fortisip_Yogurt Style Liq (3 Flav)', 4),
#  ('Omnitrope SurePal 5_Inj 5mg/1.5ml Cart', 4),
#  ('Liq Paraf Light_Gel 70%', 29),
#  ('Reltebon_Tab 5mg M/R', 4),
#  ('ClikSTAR Blue 3ml 1u (1-80u) Hypod Reusa', 2),
#  ('Infacol_Susp 40mg/ml S/F', 133),
#  ('Sod Bicarb_Oral Soln 420mg/5ml S/F', 3),
#  ('Docusate Sod_Ear Dps 0.5%', 5),
#  ('Nerisone_Oily Crm 0.1%', 3),
#  ('Opticrom_Eye Dps 2% (Aq)', 22),
#  ('Pramipexole_Tab 2.62mg M/R', 8),
#  ('Bard_Urisleeve Leg Bag Holder Sml (24-39', 2),
#  ('Mediven Elegance Class 2 B/Knee Closed T', 2),
#  ('Engerix B_Vac 20mcg/ml 1ml Pfs', 291),
#  ('Amoxicillin_Oral Susp Paed 125mg/1.25ml', 2),
#  ('Jelonet 10cm x 10cm Paraffin Ster Gz Dre', 16),
#  ('Co-Beneldopa_Cap 25mg/100mg M/R', 154),
#  ('Canesten_Crm 1%', 111),
#  ('Chloromycetin_Redidps 0.5%', 17),
#  ('Lamictal_Tab 25mg', 82),
#  ('Canagliflozin_Tab 300mg', 591),
#  ('GlucoMen GM (Reagent)_Strips', 121),
#  ('Adartrel_Tab 500mcg', 2),
#  ('Noriday_Tab 350mcg', 316),
#  ('Glyceryl Trinit_Tab 300mcg', 53),
#  ('Dermacolor_Fixing Pdr', 13),
#  ('Simvastatin_Oral Susp 40mg/5ml S/F', 6),
#  ('Beclomet Diprop_Inha 200mcg (200 D) CFF', 2),
#  ('Quinapril HCl_Tab 20mg', 64),
#  ('Emulsif_Oint', 561),
#  ('Levothyrox Sod_Oral Soln 100mcg/5ml S/F', 10),
#  ('Aquamax Crm (Appl)', 314),
#  ('Allevyn Gentle Border Sacrum 16.8x17.1cm', 17),
#  ('Desmopressin Acet_Tab 100mcg', 68),
#  ('Amias_Tab 8mg', 14),
#  ('Bisoprolol Fumar_Tab 10mg', 10326),
#  ('Teleflex_Night Drain Bag + Sle Use Tap 2', 6),
#  ('Tramulief SR_Tab 100mg', 171),
#  ('Betameth Diprop_Crm 0.05%', 7),
#  ('Coloplast_Irrigator Bag', 2),
#  ('Opus_Lift Plus 360 Medical Adh Remover S', 22),
#  ('Glipizide_Tab 5mg', 306),
#  ('Olanzapine_Tab 7.5mg', 485),
#  ('Peristeen Rectal Cath (10-Pack)', 6),
#  ('Fluconazole/Clotrimazole_Cap 150mg/Crm2%', 81),
#  ('Ramipril_Tab 1.25mg', 433),
#  ('ActiV.A.C Canister + Gel 300ml Wound Dra', 2),
#  ('Octenisan_Antimicrobial Wsh Lot', 53),
#  ('Rewisca_Cap 50mg', 85),
#  ('Derbac-M_Liq 0.5%', 4),
#  ('Coloplast_SenSura Mio Orig Midi Clsd Bag', 39),
#  ('Colomycin_Inj 1 000 000u Vl (Dry)', 14),
#  ('Balsalazide Sod_Cap 750mg', 145),
#  ('Sastravi_Tab 150mg/37.5mg/200mg', 2),
#  ('Chloroquine Phos_Tab 250mg', 4),
#  ('Gtn_Tab 300mcg', 9),
#  ('ExoCream 125g', 6),
#  ('Steristrip Skin Closure Strips Ster Surg', 11),
#  ('Diclofenac Pot_Tab 50mg', 18),
#  ('Arthrotec 75_Tab', 7),
#  ('Aripiprazole_Tab 30mg', 77),
#  ('K-Band 5cm x 4m Ktd Polyam & Cellulose C', 2),
#  ('Calc Resonium_Pdr', 2),
#  ('Lyrica_Cap 200mg', 308),
#  ('Lyrica_Cap 300mg', 1380),
#  ('Vagifem_Vag Tab 10mcg', 996),
#  ('Tobramycin_Neb Soln 300mg/5ml Amp', 2),
#  ('Liraglutide_Inj 6mg/ml 3ml PF Pen', 1776),
#  ('Mirtazapine_Orodisper Tab 30mg', 622),
#  ('EPA/DHA_Cap 460mg/380mg', 181),
#  ('Neocate Active_Pdr Sach 63g (Unflav)', 24),
#  ('Movicol_Paed Pdr Sach 6.9g (Choc)', 203),
#  ('Atomoxetine HCl_Cap 10mg', 28),
#  ('Prontoderm Foam', 9),
#  ('Alphaderm_Top Steroid Crm 1%/10%', 2),
#  ('Haelan_Crm 0.0125%', 15),
#  ('Hydrofilm 10cm x 25cm Vp Adh Film Dress', 2),
#  ('Ondansetron HCl_Oral Lyophil Tab 8mg S/F', 2),
#  ('Rewisca_Cap 75mg', 119),
#  ('Ins Aspart_Inj 100u/ml 3ml Cart', 20),
#  ('Dansac_NovaLife 1 Midi Clsd Bag + View O', 5),
#  ('Co-Amilozide_Tab 5mg/50mg', 243),
#  ('Lynlor_Cap 5mg', 4),
#  ('Fluconazole_Cap 50mg', 847),
#  ('U100 Syrg Sle Use 0.5ml + 8mm Needle-Ste', 100),
#  ('Zapain_Tab 30mg/500mg', 13370),
#  ('Zindaclin_Gel 1%', 2),
#  ('Venlafaxine_Tab 37.5mg M/R', 167),
#  ('Co-Amilofruse_Tab 5mg/40mg', 1301),
#  ('Thiamine HCl_Tab 50mg', 1995),
#  ('M.Sauer_URIbag 1.1L', 3),
#  ('Fucidin H_Crm', 536),
#  ('Olsalazine Sod_Cap 250mg', 4),
#  ('Lyofoam Max 10cm x 10cm Wound Dress Poly', 5),
#  ('Tacrolimus_Oint 0.03%', 72),
#  ('Trimethoprim_Tab 100mg', 1912),
#  ('Nova-T 380 Iucd', 9),
#  ('Premier Prestige Nitrile Blue Gloves Sml', 4),
#  ('Warburtons_G/F Bread Wte (Cut)', 32),
#  ('Synalar_Gel 0.025%', 49),
#  ('Centrum Advance_Multivit/Mineral Tab', 36),
#  ('Sondate XL_Tab 50mg', 33),
#  ('Gatalin XL_Cap 16mg', 76),
#  ('Clobetasol Prop_Scalp Applic 0.05%', 74),
#  ('Reletrans_Transdermal Patch 20mcg/hr', 9),
#  ('Candesartan Cilexetil_Tab 32mg', 2848),
#  ('Fluticasone Prop_Inh Soln 500mcg/2ml Ud', 2),
#  ('Colestyramine/Aspartame_Pdr Sach 4g S/F', 105),
#  ('Fortipine LA40_Tab 40mg', 10),
#  ('Glutafin_G/F W/F Cornflakes', 17),
#  ('Promixin_Pdr For Neb 1mega u', 8),
#  ('Aymes Shake_S/Pack Pdr', 19),
#  ('Lanthanum Carb_Tab Chble 1g S/F', 2),
#  ('Nebusal Sod Chlor 7% Inh Soln 4ml', 81),
#  ('Hollister_Moderma Flex Urost Bag Transpt', 2),
#  ('Mycophenolate Sod_Tab 180mg G/R', 4),
#  ('Sebco_Oint', 105),
#  ('Perindopril Arginine_Tab 5mg', 7),
#  ('Alfuzosin HCl_Tab 10mg M/R', 1871),
#  ('Rizatriptan_Orodisper Tab 10mg S/F', 242),
#  ('Co-Codamol_Tab 15mg/500mg', 5046),
#  ('LoFric Origo+Water Nelaton Male 40cm Siz', 43),
#  ('Rewisca_Cap 25mg', 46),
#  ('Diflucortolone Val_Crm 0.1%', 2),
#  ('Atrop Sulf_Eye Dps 1%', 109),
#  ('Dicycloverine HCl_Tab 10mg', 89),
#  ('Dapoxetine HCl_Tab 30mg', 2),
#  ('Dansac_NovaLife 1 Convex Midi Ileo Bag C', 2),
#  ('Glutafin_G/F W/F Fibre Mix', 5),
#  ('Levocarnitine_Oral Soln Paed 1.5g/5ml', 5),
#  ('Mercilon_Tab', 132),
#  ('Hollister VaPro Hydrophilic Male Size 8-', 78),
#  ('Salbulin Novolizer_Inh 100mcg (200D)+Dev', 5),
#  ('Glycopyrronium Brom_Inj 0.2mg/ml 1ml Amp', 313),
#  ('Coloplast_SenSura Soft Seal Bag Split Mi', 2),
#  ('EZY-As Compress Hose Applic', 3),
#  ('Isosorbide Mononit_Tab 25mg M/R', 206),
#  ('Stilnoct_Tab 10mg', 7),
#  ('Bisacodyl_Suppos 5mg', 12),
#  ('Salts_SecuPlast Mouldable Seals Thin', 17),
#  ('Jevity 1.5kcal_Liq', 34),
#  ('Furosemide_Tab 500mg', 15),
#  ('MXL_Cap 150mg', 8),
#  ('Desunin_Tab 800u', 2128),
#  ('Pyridox HCl_Tab 10mg', 32),
#  ('PaediaSure Plus Fibre_Liq (3 Flav)', 69),
#  ('Calci-D_Tab Chble 1g/1 000u', 24),
#  ('Fortisip Compact Fibre_Liq (3 Flav)', 105),
#  ('Erythromycin_Ethylsuc Susp 125mg/5ml', 365),
#  ('Softpore 10cm x 15cm Pfa + Adh Border Dr', 12),
#  ('Tradorec XL_Tab 100mg', 5),
#  ('Buprenorphine_Patch 52.5mcg/hr (96hr)', 51),
#  ('Adizem-XL_Cap 200mg', 182),
#  ('Mefenamic Acid_Cap 250mg', 116),
#  ('Bimatoprost_Eye Dps 100mcg/ml', 2391),
#  ('Penicillamine_Tab 125mg', 6),
#  ('Nasonex_Aq N/Spy 50mcg (140 D)', 610),
#  ('Lorazepam_Tab 2.5mg', 41),
#  ('Doxycycline Hyclate_Tab Disper 100mg S/F', 80),
#  ('Fortini_1.0 Multi Fibre Liq (4 Flav)', 18),
#  ('Co-Cyprindiol_Tab 2mg/35mcg', 295),
#  ('Respond_OstoMart Osto-EZ-Vent', 3),
#  ('Hollister_InView Incont Sheath Self-Adh', 31),
#  ('Debrisoft Lolly Physical Debridement Pad', 2),
#  ('Dansac_Nova 1 Drnbl Infant Pouch Clr C/F', 2),
#  ('Co-Codamol Eff_Tab 30mg/500mg', 2781),
#  ('Microdot Lancets 0.31mm/30 Gauge', 58),
#  ('Quinapril HCl_Tab 40mg', 51),
#  ('Oxycodone HCl_Tab 40mg M/R', 59),
#  ('Profore #2 10cm x 4.5m M/Layer Compress', 60),
#  ('Diazepam_Oral Soln 2mg/5ml S/F', 96),
#  ('Bioteque America Ring Pess Slc + No Supp', 4),
#  ('Betameth Diprop/Salic Acid_Oint 0.05/3%', 124),
#  ('Eplerenone_Tab 25mg', 2455),
#  ('Aerochamber Plus + Adult/Child/Infant Ma', 3386),
#  ('Liq Paraf/Acetyl Wool Alc_Bath Oil 65/5%', 2),
#  ('Gatalin XL_Cap 24mg', 98),
#  ('Glimepiride_Tab 2mg', 1131),
#  ('Ofloxacin_Eye Dps 0.3%', 41),
#  ('M.Sauer_NephSys Ster Drain Bag 500ml 30c', 3),
#  ('Biquelle XL_Tab 200mg', 26),
#  ('Estradiol_Patch 50mcg/24hrs (AMQ8)', 20),
#  ('Mag Glycerophos_Cap 97.2mg', 2),
#  ('Epilim_Liq 200mg/5ml S/F', 369),
#  ('Etoricoxib_Tab 90mg', 373),
#  ('Piriton_Syr 2mg/5ml', 213),
#  ('Nedocromil Sod_Inha 2mg (112 D) CFF', 4),
#  ('Luventa XL_Cap 24mg', 73),
#  ('Oxycodone HCl_Tab 30mg M/R', 27),
#  ('Cutimed Sorbact Swab 4cm x 6cm Gz Dress', 35),
#  ('Clexane_Inj 100mg/ml 0.8ml Pfs', 7),
#  ('PF Drops Hypromellose 0.3% Eye Dps 10ml', 13),
#  ('Savlon_Antis Crm', 11),
#  ('Havrix Monodose_Vac 50u/ml 1ml Vl', 8),
#  ('WaveSense JAZZ (Reagent)_Strips', 1450),
#  ('Ugo Fix Gentle Clip For Foy Cath Access', 2),
#  ('Loratadine_Oral Soln 5mg/5ml', 474),
#  ('Dilzem SR 60_Cap 60mg', 158),
#  ('Amoxil_Cap 500mg', 38),
#  ('Calc Carb_Tab Chble 1.5g (600mg) S/F', 341),
#  ('Exorex_Lot', 123),
#  ('Duloxetine HCl_Cap G/R 30mg', 2845),
#  ('Vildagliptin/Metformin HCl_Tab 50mg/1g', 109),
#  ('Oxycodone HCl_Oral Soln 10mg/1ml S/F', 12),
#  ('Ins Lispro_Inj 100u/ml 10ml Vl', 6),
#  ('BuTrans_Transdermal Patch 5mcg/hr', 383),
#  ('Convatec_Combihesive Natura Flx Flng 45m', 8),
#  ('Zn Sulf_Cap 220mg', 16),
#  ('Zetuvit E (Non-Ster) 20cm x 20cm Pfa Cel', 2),
#  ('Methylphenidate HCl_Tab 20mg', 38),
#  ('Kemadrin_Tab 5mg', 171),
#  ('Omnican Lance Soft 0.3mm/30 Gauge', 74),
#  ('Audmonal_Forte Cap 120mg', 19),
#  ('Ins Insuman Basal SoloStar_3ml Pf Pen', 108),
#  ('Cetaphil_Moist Lot', 2),
#  ('Systane Gel Dps Hydroxypropyl Guar Eye D', 31),
#  ('Senna_Oral Soln 7.5mg/5ml S/F', 1493),
#  ('Epilim Chrono 300_Tab 300mg C/R', 1273),
#  ('ActivHeal Aquafiber Rope 2cm x 42cm Woun', 4),
#  ('Sod Feredetate_Oral Soln 190mg/5ml S/F', 802),
#  ('GlucoGel_Gel 40% (Original)', 309),
#  ('Augmentin-Duo 400/57_Pdr For Susp S/F', 5),
#  ('Isosorbide Mononit_Tab 40mg', 430),
#  ('Pro-Banthine_Tab 15mg', 4),
#  ('Spironol_Tab 25mg', 7914),
#  ('Coloplast_Assura Insp Closed Bag +D/Fltr', 3),
#  ('Morph Sulf_Cap 100mg M/R', 5),
#  ('Dansac_Nova 1 Urost Pouch C/exity Transp', 4),
#  ('Dansac_Nova 1 Convex Urost Pouch Clr C/F', 4),
#  ('Zaluron XL_Tab 150mg', 13),
#  ('Erythromycin_Cap E/C 250mg', 66),
#  ('Trio_Elite Sting Free Adh Remover Spy 50', 19),
#  ('Gaviscon_Liq Relief Peppermint', 223),
#  ('Doublebase_Gel', 6386),
#  ('Minims_Prednisolone Sod Phos Ud 0.5%', 8),
#  ('Adizem-XL_Cap 240mg', 446),
#  ('Pethidine HCl_Tab 50mg', 11),
#  ('Imigran 50_Tab 50mg', 2),
#  ('Liq Paraf/Wte Soft Paraf_Oint 5%/95%', 17),
#  ('Aveeno_Daily Moist Lot', 12),
#  ('Juvela_G/F Bread Roll Wte', 27),
#  ('Evacal D3_Tab Chble 400u/1.5g', 1803),
#  ('CosmoCol_Oral Pdr Sach (Orng Lem & Lim)', 215),
#  ('Ethinylestr/Gestodene_Tab 30mcg/75mcg', 4),
#  ('Fostair NEXThaler_Inh 100mcg/6mcg (120D)', 1189),
#  ('Cilest_Tab', 993),
#  ('Prednisolone_Tab 2.5mg', 210),
#  ('Salts_Confidence Natural Soft Convex Cls', 38),
#  ('Hydrofilm Plus 9cm x 10cm VP Adh Film Dr', 5),
#  ('Clobazam_Oral Susp 5mg/5ml S/F', 35),
#  ('Aclidinium Brom_Pdr For Inh 375mcg (60D)', 626),
#  ('Dimeticone/Benzalk Chlor_Crm 22%/0.1%', 62),
#  ('Jevity Promote_Liq', 6),
#  ('Allevyn 5cm x 5cm Wound Dress Polyureth', 11),
#  ('Trifluoperazine_Tab 1mg', 35),
#  ('Hollister_Urost Night Drain Bag', 15),
#  ('Efexor XL_Cap 75mg', 9),
#  ('Levomeprom Mal_Tab 25mg', 53),
#  ('Zestril_Tab 20mg', 4),
#  ('Pelican_Select Closed Convex Pouch Clr S', 13),
#  ('Calogen_Emuls (Sbery)', 48),
#  ('Oilatum_Scalp Intensive Tt Shampoo', 8),
#  ('Alfacalcidol_Cap 500ng', 682),
#  ('Morph Sulf_Tab 60mg M/R', 98),
#  ('Ins Humulin I_100u/ml 3ml Cart', 163),
#  ('Tegaderm Foam Adh Oval 10cm x 11cm Wound', 240),
#  ('Reltebon_Tab 15mg M/R', 3),
#  ('Hyoscine Butylbrom_Inj 20mg/ml 1ml Amp', 155),
#  ('Questran_Sach 9g (4g Of Ingredient)', 10),
#  ('Irbesartan_Tab 300mg', 4033),
#  ('Tranexamic Acid_Tab 500mg', 1692),
#  ('Gaviscon Double Action_Tab Chble', 79),
#  ('Metalline 8cm x 9cm Tracheo Dress Ster', 2),
#  ('Salicylic Acid/Mucopolysac_Crm 2%/0.2%', 150),
#  ('Thin Lancets 0.36mm/28 Gauge', 21),
#  ('Stalevo_Tab 75mg/18.75mg/200mg', 5),
#  ('Colchicine_Tab 500mcg', 1635),
#  ('Fluoxetine HCl_Cap 10mg', 75),
#  ('Forticreme Complete_Dessert (Choc)', 65),
#  ('Mag Trisil_Mix', 3),
#  ('Jext_Inj 1/1000 0.15ml Pf Pen Autoinject', 11),
#  ('Folic Acid_Oral Soln 2.5mg/5ml S/F', 336),
#  ('Ster Dress Pack + Non-Wov Pads Vernaid', 6),
#  ('Unspec Drug Code_(Discount Not Deducted)', 27),
#  ('Diltiazem HCl_Cap 60mg M/R', 164),
#  ('Salicylic Acid/Mucopolysac_Gel 2%/0.2%', 741),
#  ('Telmisartan_Tab 20mg', 158),
#  ('LoFric Primo Nelaton Fle Non-PVC 20cm 8-', 7),
#  ('Regurin_Tab 20mg', 2),
#  ('Allevyn Gentle 10cm x 10cm Wound Dress S', 4),
#  ('Cetraben Lot 500ml', 57),
#  ('Gz & Cott Tiss BP 1988', 7),
#  ('Ampicillin_Cap 250mg', 2),
#  ('Fragmin_Inj 25 000u/ml 0.2ml Pfs', 9),
#  ('Bard All Slc Foy Male/Stnd 10ml 12-22 Ca', 2),
#  ('Levetiracetam_Tab 500mg', 2798),
#  ('kliniderm superabsorbent 10cm x 15cm Pfa', 8),
#  ('Hydromol Intensive_Crm 10%', 25),
#  ('Erdotin_Cap 300mg', 4),
#  ('Isodur 25 XL_Cap 25mg', 17),
#  ('Flurbiprofen_Loz 8.75mg', 15),
#  ('Cetirizine HCl_Tab 10mg', 18780),
#  ('Aspen_Sorbaderm No-Sting Barrier Film 1m', 316),
#  ('Dip Tet Polio Inact (Ad)_Vac 0.5ml Pfs', 25),
#  ('Nabumetone_Tab 500mg', 60),
#  ('Mediven Elegance Class 1 B/Knee Closed T', 2),
#  ('Clarithromycin_Oral Susp 125mg/5ml', 689),
#  ('Fluticasone/Salmeterol_Inh 125/25mcg120D', 1593),
#  ('Pericyazine_Tab 2.5mg', 7),
#  ('H & R_Proshield Foam & Spy Skin Cleanser', 763),
#  ('Zuclopenth HCl_Tab 25mg', 11),
#  ('Co-Careldopa_Tab 25mg/250mg', 5),
#  ('Liq Paraf_Bath Add 65%', 2),
#  ('Duloxetine HCl_Cap G/R 20mg', 405),
#  ('Amitriptyline HCl_Oral Soln 25mg/5ml S/F', 22),
#  ('Aquacel Ag Ribbon 2cm x 45cm Wound Dress', 15),
#  ('Tabphyn MR_Cap 400mcg (Kyowa)', 495),
#  ('Fifty:50 Oint', 10),
#  ('Optiflo G Cath Maint Soln 50ml', 68),
#  ('One-Alpha_Cap 1mcg', 27),
#  ('Pregnacare_Tab', 95),
#  ('Betagan_Eye Dps 0.5%', 10),
#  ('Fresubin Orig Tube Feed_Liq (Unflav)', 3),
#  ('Lisinopril/Hydchloroth_Tab 20mg/12.5mg', 328),
#  ('Levothyrox Sod_Tab 75mcg', 4),
#  ('Topiramate_Tab 200mg', 162),
#  ('Fresubin Thickened Stage 2_Cust (2 Flav)', 17),
#  ('Glutafin_G/F Roll x 2 Wte Long P/Bke', 2),
#  ('Myfortic_Tab 180mg G/R', 2),
#  ('Norgalax_Micro-Enem 120mg 10g Tube', 2),
#  ('Timolol_Eye Dps 0.25%', 589),
#  ('Phenelzine Sulf_Tab 15mg', 17),
#  ('Brivaracetam_Tab 50mg', 3),
#  ('Tetralysal 300_Cap', 488),
#  ('Adaptic Touch 7.6cm x 11cm Wound Dress S', 3),
#  ('Bard_Uriplan Leg Bag 30cm Inlet Tube 750', 7),
#  ('CliniMed_Hyperseal Washers+Manuka HoneyS', 2),
#  ('Iglu_Oral Gel', 2),
#  ('Rochester_Clr Advantage Slc Sheath Lge 3', 2),
#  ('Trimipramine Mal_Tab 25mg', 17),
#  ('Maxitram SR_Cap 50mg', 100),
#  ('Gaviscon Cool_Tab Chble 250mg (P/Mint)', 4),
#  ('Zetuvit E 20cm x 40cm Pfa Cellulose Dres', 81),
#  ('Matrifen_Patch 100mcg/hr', 125),
#  ('FemSeven Sequi_Patch', 2),
#  ('Atrauman 5cm x 5cm Ktd Polyester Dress', 146),
#  ('ActivHeal Foam Adh 10cm x 10cm Wound Dre', 91),
#  ('Buprenorphine_Patch 10mcg/hr (7day)', 1181),
#  ('Prednisolone Sod Phos_Ear/Eye Dps 0.5%', 8),
#  ('Coloplast Self-Cath Nelaton Fle Size 10-', 2),
#  ('Propantheline Brom_Tab 15mg', 178),
#  ('Nutramigen 2 LIPIL_Pdr', 200),
#  ('Mebendazole_Oral Susp 100mg/5ml', 334),
#  ('Ditropan_Tab 2.5mg', 47),
#  ('Alendronic Acid/Colecal_Tab 70mg/70mcg', 2),
#  ('ClobaDerm_Crm 0.05%', 11),
#  ('Latanoprost_Eye Dps 50mcg/ml', 9181),
#  ('Madopar_Cap 50mg/12.5mg', 324),
#  ('Lubiprostone_Cap 24mcg', 5),
#  ('Chlorhex Glucon_Soln 1%', 3),
#  ('Sod Cromoglicate_Eye Dps Aq 2%', 2962),
#  ('Microgynon 30 ED_Tab', 280),
#  ('Azathioprine_Tab 50mg', 2472),
#  ('Dexameth_Tab 4mg', 2),
#  ('Scanpor 2.5cm x 5m Surg Adh Tape Perm No', 14),
#  ('Actilite 10cm x 10cm Manuka Honey Ster G', 4),
#  ('Acetazolamide_Tab 250mg', 182),
#  ('Foodlink_Complete Pdr (4 Flav)', 233),
#  ('Valupak_Vit B Comp Tab OAD', 2),
#  ('Dansac_Nova 1 Maxi E/Fld Soft Drnbl Bag', 13),
#  ('Flixotide_Accuhaler 50mcg (60 D)', 3),
#  ('Allopurinol_Tab 100mg', 11901),
#  ('Sod Clodronate_Tab 800mg', 7),
#  ('Imigran_Tab 100mg', 13),
#  ('Aspirin/Metoclop_Pdr Sach 900mg/10mg S/F', 4),
#  ('Pro D3_Cap 20 000u', 153),
#  ('Sandrena_Gel Sach 500mcg/0.5g', 7),
#  ('Avodart_Soft Cap 500mcg', 2),
#  ('Respond_OstoMart Cool Comfort Unisex Gmt', 7),
#  ('Lisinopril_Tab 5mg', 8404),
#  ('E45_Intense Recovery Lot', 4),
#  ('Avaxim_Vac 320u/ml 0.5ml Pfs', 307),
#  ('Strontium Ranelate_Susp Gran Sach 2g S/F', 70),
#  ('Allevyn Gentle 5cm x 5cm Wound Dress Sof', 3),
#  ('Fenofibrate_Cap 200mg (Micronised)', 538),
#  ('Glutafin_G/F W/F Lasagne', 9),
#  ('Slo-Phyllin_Cap 60mg', 22),
#  ('Omeprazole_Oral Susp 10mg/5ml', 60),
#  ('Metformin HCl_Tab 750mg M/R', 669),
#  ('Memantine HCl_Tab 10mg', 1395),
#  ('Hypafix 10cm x 10m Surg Adh Tape Perm No', 42),
#  ('Sudafed_Decongest Liq 30mg/5ml', 2),
#  ('Chlordiazepox HCl_Cap 5mg', 83),
#  ('Ropinirole HCl_Tab 250mcg', 226),
#  ('CosmoCol_Oral Pdr Sach (Plain)', 185),
#  ('Pregabalin_Cap 50mg', 2078),
#  ('Celecoxib_Cap 200mg', 405),
#  ('Ocuvite_Lutein Cap', 10),
#  ('Unspecified Stkntte 7.5cm x 0.5m Elasctd', 2),
#  ('Meptazinol HCl_Tab 200mg', 257),
#  ('Lacidipine_Tab 2mg', 926),
#  ('Half Sinemet CR_Tab 125mg', 261),
#  ('Salamol_Inha 100mcg (200 D) CFF (Teva)', 1011),
#  ('Enfamil O-Lac_Pdr', 5),
#  ('Nutrison Pack_Energy', 29),
#  ('GlucoRx Nexus (Reagent)_Strips', 3637),
#  ('Dansac_Nodor S Deod 50ml', 2),
#  ('GlucoRx Safety Lancets 1.6mm/30 Gauge', 12),
#  ('Roaccutane_Cap 10mg', 14),
#  ('Calogen_Emuls (Neutral)', 53),
#  ('Estradiol_Patch 100mcg/24hrs (AMQ8)', 8),
#  ('Oxis 12_Turbohaler 12mcg (60 D)', 14),
#  ('Balneum Crm', 149),
#  ('Spiroco XL_Tab 8mg', 2),
#  ('Provox Fltr HME Xtrabase Adh 7265 Trache', 2),
#  ('Coloplast_Brava Ostomy Pdr', 10),
#  ('Actico 8cm x 6m Short Stch Compress Band', 17),
#  ('ConvaTec_Esteem+ Drnbl Pch+Invis Outl Mo', 2),
#  ('Epanutin_Susp 30mg/5ml', 6),
#  ('KerraContact Ag 15cm x 15cm Wound Dress', 4),
#  ('Hydromorphone HCl_Cap 8mg M/R', 2),
#  ('Vigabatrin_Pdr Sach 500mg S/F', 8),
#  ('Psoriderm_Scalp Lot', 2),
#  ('Carbocisteine_Soln750mg/10mlSach10ml S/F', 69),
#  ('Eliquis_Tab 5mg', 2),
#  ('Amiodarone HCl_Tab 200mg', 1501),
#  ('Beclomet/Formoterol_Inh 100/6 (120D) Dry', 108),
#  ('Spironol_Tab 50mg', 1310),
#  ('DuoDERM Ex Thin 5cm x 10cm Wound Dress H', 4),
#  ('Permethrin_Crm 5%', 764),
#  ('Phenoxymethylpenicillin_Soln 250mg/5mlSF', 330),
#  ('Ametop_Gel 4%', 14),
#  ('VSL#3_Probiotic Food Supp Pdr Sach 4.4g', 18),
#  ('Elleste Duet Conti_Tab', 253),
#  ('Fresubin Orig_Drink (5 Flav)', 5),
#  ('Diamorph HCl_Inj 30mg Amp', 11),
#  ('Alphagan_Eye Dps 0.2%', 56),
#  ('Rizatriptan_Tab 5mg', 6),
#  ('Co-Dydramol_Tab 10mg/500mg', 10072),
#  ('Glutafin_G/F W/F H/Fbre Cracker', 9),
#  ('Meloxicam_Tab 7.5mg', 786),
#  ('Prednisolone Sod Phos_Eye Dps 0.5% Ud', 36),
#  ('Natrilix_Tab 2.5mg', 15),
#  ('BD Viva Needles Pen Inj Screw On 4mm/32', 89),
#  ('Ins Tresiba_Penfill 100u/ml 3ml Cart', 11),
#  ('Dulaglutide_Inj 1.5mg/0.5ml Pf Dev', 176),
#  ('Comfifast 10.75cm x 3m (Yellow)Stkntte E', 14),
#  ('Polytar_Scalp Shampoo', 2),
#  ('kliniderm superabsorbent 10cm x 10cm Pfa', 10),
#  ('Glutafin_G/F Bread Roll x 4 Wte', 23),
#  ('Neria Subcutaneous D/Delivery Acc 110cm', 5),
#  ('Nizatidine_Cap 300mg', 13),
#  ('OpSite Post-Op 10cm x 20cm VP Adh Film D', 3),
#  ('Gentamicin Sulf_Inj 40mg/ml 2ml Amp', 2),
#  ('Bonviva_Tab 150mg F/C', 2),
#  ('Neoral_Cap 25mg', 24),
#  ('Engerix B_Vac Paed 20mcg/ml 0.5ml Pfs', 53),
#  ('Estradot_Patch 75mcg/24hrs', 6),
#  ('Sando-K_Tab Eff 470mg', 174),
#  ('Cerumol_Ear Dps', 83),
#  ('Irriclens Sod Chlor Top Irrig A/Spy 240m', 114),
#  ('Donepezil HCl_Orodisper Tab 10mg S/F', 69),
#  ('ExoCream 50g', 5),
#  ('Canesten_Thrush Crm 2%', 13),
#  ('OneTouch Comfort Lancets 0.20mm/33 Gauge', 11),
#  ('Nicotine_Oromucosal P/Spy (1mg D) S/F', 28),
#  ('NiQuitin_Patch 21mg/24hrs (Step 1)', 15),
#  ('Beambridge_Bridge Saddle Urin', 2),
#  ('Dosulepin HCl_Cap 25mg', 1853),
#  ('Thick & Easy_Food Thickener Pdr Sach 9g', 32),
#  ('Lacosamide_Tab 50mg', 53),
#  ('Zonegran_Cap 100mg', 8),
#  ('Cath-It Insertion/Removal Pack Med/Lge C', 7),
#  ('Respond_OstoMart OstoMist Odour Neutrali', 3),
#  ('Allevyn 10cm x 10cm Wound Dress Polyuret', 11),
#  ('Povidone-Iodine_Pdr Spy 2.5% 100ml', 10),
#  ('Risperidone_Inj Pdr 25mg Vl + Dil', 2),
#  ('Ramipril_Tab 2.5mg', 1205),
#  ('Furosemide_Oral Soln 40mg/5ml S/F', 63),
#  ('Pholcodine_Oral Soln 2mg/5ml S/F', 21),
#  ('Diethylamine Sal_Crm 10% BP', 1543),
#  ('Galantamine_Cap 24mg M/R', 99),
#  ('Juvela_G/F W/F Tagliatelle', 8),
#  ('Adcal-D3_Tab Chble (Lem)', 3797),
#  ('Rotigotine_Transdermal Patch 8mg/24hrs', 51),
#  ('Olanzapine_Orodisper Tab 20mg', 50),
#  ('Methotrexate_Inj 20mg/0.4ml PF Dev', 71),
#  ('Allevyn Adh 12.5cm x 12.5cm Wound Dress', 52),
#  ('Vortioxetine_Tab 20mg', 15),
#  ('Convatec_Clips (Beige) (1-Piece Pouch)', 2),
#  ('Limb LimbO Adult 1/2 Leg Lge Build/Short', 2),
#  ('Ponstan_Cap 250mg', 5),
#  ('Minims_Artificial Tears Ud P/F', 52),
#  ('Betameth Sod Phos_Tab Solb 500mcg', 69),
#  ('Coloplast_SenSura Soft Seal Maxi Split S', 11),
#  ('Ins Apidra SoloStar_100u/ml 3ml PF Pen', 272),
#  ('Agrippal_Vac 0.5ml Pfs', 45),
#  ('Norethist_Tab 350mcg', 157),
#  ('Trimipramine Mal_Cap 50mg', 89),
#  ('Risperdal_Oral Soln 1mg/1ml', 2),
#  ('Hyetellose_Eye Dps 0.44% Ud', 2),
#  ('Ranitidine HCl_Tab Eff 300mg', 4),
#  ('Cutimed Siltec 10cm x 10cm Wound Dress S', 4),
#  ('CliniSupplies_ProSys Night Bag Lever Out', 28),
#  ('Saliveze_Dry Mth P/Spy 50ml', 34),
#  ('U100 Syrg Sle Use 1ml + 12mm Needle-Ster', 27),
#  ('MXL_Cap 200mg', 5),
#  ('Renagel_Tab 800mg', 6),
#  ('Methylpred Acet_Inj 40mg/ml 3ml Vl', 3),
#  ('Allevyn Gentle Border 10cm x 10cm Wound', 369),
#  ('Vigabatrin_Tab 500mg', 4),
#  ('Humapen Savvio Graphite 3ml 1u (1-60u) H', 2),
#  ('Glutafin_G/F Wte Bread (Cut)', 12),
#  ('Adoport_Cap 2mg', 4),
#  ('BD Micro-Fine + Lancets 0.20mm/33 Gauge', 52),
#  ('Celluvisc_Eye Dps 1% 0.4ml Ud', 561),
#  ('Pyridox HCl_Tab 50mg', 310),
#  ('Xatral_XL Tab 10mg', 39),
#  ('Dansac_Nova Colo Bag Opqe P/Cut 30mm', 2),
#  ('Amitriptyline HCl_Tab 25mg', 13827),
#  ('Minocycline HCl_Tab 100mg', 2),
#  ('Esomeprazole_Gran Sach G/R 10mg', 5),
#  ('Coloplast_Brava Skin Barrier Crm 60ml', 4),
#  ('Dexameth_Eye Dps 0.1% 0.5ml Ud P/F', 8),
#  ('Memantine HCl_Oral Soln 10mg/ml S/F', 103),
#  ('Hypafix 5cm x 10m Surg Adh Tape Perm Non', 21),
#  ('Cathejell Mono Lubricant Gel 12.5g', 31),
#  ('Neutrogena_T/Gel 2 in 1 Shampoo & Cond', 10),
#  ('BD Microfine+ Needles Pen Inj Screw On 8', 621),
#  ('Imigran Subject_Inj 6mg/0.5ml Ref', 4),
#  ('Prempak-C_C/Pk Tab 1.25mg/150mcg', 44),
#  ('Unomedical_Careline E4 Urine Drain Bag 2', 2),
#  ('Tolterodine_Cap 4mg M/R', 1093),
#  ('Dovonex_Oint 50mcg/1g', 100),
#  ('Ethinylestr_Tab 10mcg', 4),
#  ('Sod Alginate/Pot Bicarb_Tab Chble 500mg', 200),
#  ('Diltiazem HCl_Cap 90mg M/R', 163),
#  ('Longtec_Tab 80mg M/R', 157),
#  ('Clinipore 1.25cm x 5m Surg Adh Tape Perm', 5),
#  ('Glutafin_G/F W/F Diges Bisc', 20),
#  ('Mag Aspartate (Mag 10mmol)_Oral Pdr Sach', 34),
#  ('Estradiol_Val Tab 2mg', 78),
#  ('Levetiracetam_Gran Sach 250mg S/F', 3),
#  ('Synalar_Oint 0.025%', 2),
#  ('Fenbid Fte_Gel 10%', 1666),
#  ('Nystatin_Oral Susp 100 000u/ml', 1358),
#  ('Prasugrel_Tab 10mg', 252),
#  ('OptiLube Ster Lubri Jelly Sach 5g', 4),
#  ('Gppe Oint_Metanium', 26),
#  ('Vita-E_Gels 75u', 9),
#  ('Simvastatin_Oral Susp 20mg/5ml S/F', 2),
#  ('Calcichew D3 Fte_Tab Chble', 5465),
#  ('Bactroban_Oint 2%', 5),
#  ('Triamcinol Aceton_Inj 10mg/ml 1ml Amp', 13),
#  ('Pseudoephed HCl_Oral Soln 30mg/5ml', 46),
#  ('Fortini_Multi Fibre Liq (4 Flav)', 10),
#  ('Saline Steripoule_Inh Soln 0.9% 2.5ml Ud', 198),
#  ('Dermatix Gel 15g Wound Dress Slc', 4),
#  ('Trental 400_Tab 400mg', 3),
#  ('Colecal & Calc_Tab Chble 800u/2.5g', 18),
#  ('Enoxaparin_Inj 150mg/ml 0.8ml Pfs', 52),
#  ('DesmoMelt_Oral Lyoph 240mcg', 39),
#  ('Robitussin_Chesty Cough Liq 100mg/5ml', 2),
#  ('Saxagliptin_Tab 2.5mg', 246),
#  ('Sulfasalazine_Tab E/C 500mg', 1454),
#  ('Topiramate_Tab 25mg', 1283),
#  ('Forticreme Complete_Dessert (Vanilla)', 66),
#  ('Ensure Plus Commence_Liq (2200 (10x220)', 2),
#  ('Vildagliptin_Tab 50mg', 117),
#  ('Unilet Eco Lancets 0.375mm/28 Gauge', 14),
#  ('Sacubitril/Valsartan_Tab 97mg/103mg', 2),
#  ('Duraphat_Fluoride Toothpaste (2800ppm)', 31),
#  ('Welland_FreeStyle Vie Closed Pouch Clr L', 2),
#  ('Zopiclone_Tab 7.5mg', 14093),
#  ('Binosto_Eff Tab 70mg', 3),
#  ('Indacaterol Mal_Pdr Inh Cap 150mcg + Dev', 65),
#  ('Hydrocort_Crm 2.5%', 59),
#  ('Maalox_Susp 195mg/220mg/5ml S/F', 44),
#  ('Glandosane A/Spy 50ml (App)', 615),
#  ('Liq Paraf Light/Wte Soft Paraf_Crm 6/15%', 31),
#  ('Phenoxymethylpenicillin_Soln 250mg/5ml', 1238),
#  ('Manevac_Gran', 151),
#  ('Nitrolingual_P/Spy 400mcg (200 D)', 88),
#  ('Sod Chlor_I/V Inf 0.9% 10ml Amp', 34),
#  ('Gliclazide_Tab 30mg M/R', 2384),
#  ('Bimatoprost/Timolol_Eye Dps 300mcg/5mg', 1718),
#  ('Coloplast_SenSura Midi Closed Bag Transp', 4),
#  ('Movicol-Half_Pdr Sach 6.9g (Lem & Lim)', 108),
#  ('Fortisp_2kcal (2 Flav)', 25),
#  ('Cefradine_Cap 250mg', 28),
#  ('Algivon 10cm x 10cm Wound Dress Algin St', 2),
#  ('Fluoxetine HCl_Cap 20mg', 27574),
#  ('Seretide 500_Accuhaler 500mcg/50mcg(60D)', 4364),
#  ('Allopurinol_Tab 300mg', 9545),
#  ('Alogliptin_Tab 12.5mg', 254),
#  ('ActivHeal 10cm x 10cm Non-Adh Foam Wound', 5),
#  ('Bricanyl_Turbohaler 500mcg (100 D)', 527),
#  ('Hydrocort But_Crm 0.1%', 31),
#  ('Aciclovir_Tab Disper 800mg', 33),
#  ('Diazepam_Tab 5mg', 8224),
#  ('Versatis_Medic Plastr 5%', 98),
#  ('Cuplex Verruca_Gel', 18),
#  ('Alogliptin_Tab 25mg', 1508),
#  ('Imuvac_Vac 0.5ml Pfs', 859),
#  ('BD AutoShield Duo Needles Pen Inj Screw', 338),
#  ('Cetraben Crm 1050g', 76),
#  ('Methylcellulose_Tab 500mg', 45),
#  ('Moclobemide_Tab 150mg', 2),
#  ('Pelican_Deo-Mint Deod', 2),
#  ('Colecal_Oral Dps 2 000u/ml S/F', 9),
#  ('Glibenclamide_Tab 5mg', 4),
#  ('Miconazole Nit_Vag Crm 2% + Applic', 9),
#  ('Comfifast E/Wrap Vest L/S 2-5 Yrs Elasct', 2),
#  ('Verapamil HCl_Tab 40mg', 463),
#  ('Benzalk Chlor_Shampoo 0.5%', 22),
#  ('Xupad Dress Pad Ster 20cm x 40cm', 39),
#  ('Aciferol D3_Tab 10 000u', 18),
#  ('Ins Humulin M3_KwikPen 100u/ml 3ml PfPen', 2225),
#  ('Oxybutynin HCl_Tab 2.5mg', 2737),
#  ('Fluticasone/Azelastine_Spy50/137mcg 120D', 259),
#  ('Diazepam_Soln 5mg/2.5ml Rectal Tube', 2),
#  ('Betameth Val_Scalp Applic 0.1%', 1869),
#  ('Co-Codamol_Cap 15mg/500mg', 903),
#  ('Cabergoline_Tab 0.5mg', 159),
#  ('Pizotifen Malate_Tab 1.5mg', 1145),
#  ('Canesten_Oral&Crm Duo(1 Cap 150mg/Crm2%)', 2),
#  ('Amlodipine_Oral Soln 10mg/5ml S/F', 4),
#  ('Fluorome_Eye Dps 0.1%', 29),
#  ('Phenobarb_Tab 30mg', 501),
#  ('Rochester_UltraFlex Clr Slc Sheath Self-', 4),
#  ('OneTouch Delica Lancets 0.32mm/30 Gauge', 272),
#  ('Co-Codamol_Tab 30mg/500mg', 24114),
#  ('Co-Beneldopa_Tab Disper 12.5mg/50mg S/F', 135),
#  ('Lipitor_Tab 20mg', 47),
#  ('Aciclovir_Tab 200mg', 751),
#  ('Bard_Leg Bag Straps (Washable)', 9),
#  ('Coloplast_Comfeel Barrier Crm', 6),
#  ('Convatec_Orabase Paste 30g', 71),
#  ('Sinemet CR_Tab 250mg', 97),
#  ('Rivastigmine_Skin Patch 9.5mg/24hrs', 260),
#  ('Clenil Modulite_Inha 250mcg (200D)', 508),
#  ('Cefalexin_Tab 500mg', 141),
#  ('Oxcarbazepine_Tab 150mg', 28),
#  ('Pioglitazone HCl_Tab 15mg', 1077),
#  ('Venlalic XL_Tab 37.5mg', 37),
#  ('Frebini_Energy Liq (2 Flav)', 5),
#  ('Multi-thick_Pdr', 3),
#  ('Comfifast 7.5cm x 5m (Blue) Stkntte Elas', 204),
#  ('Kavendor_Comfizz Stoma Support Wear Jnr', 4),
#  ('Propranolol HCl_Tab 40mg', 9315),
#  ('OxyNorm_Inj 10mg/ml 1ml Amp', 2),
#  ('Sterculia_Gran 62% Sach 7g G/F', 3),
#  ('Liskonum_Tab 450mg M/R', 2),
#  ('Beclomet Diprop_Inha 100mcg (200 D) CFF', 303),
#  ('Clopidogrel_Tab 75mg', 37400),
#  ('Scheriproct_Oint', 765),
#  ('Coloplast SpeediCath Compact Plus Fle 10', 76),
#  ('Atomoxetine HCl_Cap 80mg', 30),
#  ('Kendall AMD 5cm x 5cm Wound Dress Polyur', 2),
#  ('Buprenorphine_Patch 35mcg/hr (96hr)', 139),
#  ('Haloperidol_Inj 5mg/ml 1ml Amp', 153),
#  ('CosmoCol_Oral Pdr Sach (Orange)', 748),
#  ('Pariet_Tab E/C 20mg', 9),
#  ('Qvar 50_Autohaler 50mcg (200 D)', 46),
#  ('Loceryl Curanail_Medic Nail Lacquer 3ml', 2),
#  ('Glutafin_G/F Fibre Bread (Cut)', 10),
#  ('Kalcipos-D_Tab Chble 800u/500mg', 13),
#  ('Solaraze_Gel 3%', 90),
#  ('Welland_FreeStyle Vie Convex Drnbl Pch L', 4),
#  ('PF Drops 0.5% Carmellose Eye Dps 10ml', 23),
#  ('Sulfasalazine_Tab 500mg', 890),
#  ('Eesiban 7.5cm x 5m Stkntte Ribbed Tublr', 9),
#  ('Isosorbide Dinit_Tab 40mg M/R', 4),
#  ('Clonidine HCl_Tab 25mcg', 2030),
#  ('Myocrisin_Inj 100mg/ml 0.5ml Amp', 12),
#  ('Bupeaze_Transdermal Patch 35mcg/hr(96hr)', 5),
#  ('Coloplast Folysil X-Tra Slc O/End Male 1', 11),
#  ('Glutafin Select_G/F Bread Mix', 6),
#  ('N-A Dress 9.5cm x 9.5cm Type 1 Ktd Visco', 8),
#  ('Simvastatin_Tab 80mg', 1093),
#  ('Dansac_Seals 30mm (57.5mm Outer Diam)', 4),
#  ('Methotrexate_Inj 15mg/0.3ml PF Dev', 45),
#  ('Rinatec_Aq Nsl Spy 21mcg (180D) 15ml CFF', 45),
#  ('Mission Ketone (Reagent)_Strips', 14),
#  ('Mefix 5cm x 5m Surg Adh Tape Perm Non-Wo', 45),
#  ('Haddenham Custom Pertex L/Limb Acc Slc G', 4),
#  ('PolyMem 10cm x 10cm Wound Dress Polyuret', 7),
#  ('Bard_Uriplan Leg Bag 10cm Inlet Tube 750', 2),
#  ('Haloperidol Decan_Inj 50mg/ml 1ml Amp', 3),
#  ('CliniMed_LBF Barrier Crm', 23),
#  ('Hydromoor Hypromellose Eye Dps 0.4ml Ud', 50),
#  ('Glutafin_G/F Multipurpose Wte Mix', 47),
#  ('Medikinet XL_Cap 5mg', 30),
#  ('Calc Acet_Tab 475mg', 6),
#  ('Fluticasone/Formoterol_Inh 125/5mcg 120D', 244),
#  ('Ranitidine HCl_Tab 300mg', 4158),
#  ('Diazepam_Tab 2mg', 11160),
#  ('Coban 2 One Size M/Layer Compress Bandag', 8),
#  ('Salts_SecuPlast Mouldable Seals Stnd', 3),
#  ('Calcichew Fte_Chble Tab 2.5g', 15),
#  ('Dansac_Non Sting Adh Remover Sach', 7),
#  ('FruitiVits_Pdr Sach 6g', 2),
#  ('K-Band 10cm x 4m Ktd Polyam & Cellulose', 23),
#  ('Duaklir Genuair_340mcg/12mcg (60D)', 274),
#  ('Acetazolamide_Cap 250mg M/R', 44),
#  ('Mirtazapine_Tab 15mg', 11744),
#  ('Vitalograph Stnd Range Peak Flow Meter H', 7),
#  ('Paracet_Oral Susp Paed 120mg/5ml S/F', 3159),
#  ('CellCept_Cap 250mg', 5),
#  ('Aptamil_Pepti 1 Pdr', 178),
#  ('CareSens Lancets 0.36mm/28 Gauge', 705),
#  ('Colecal_Tab 10 000u', 11),
#  ('Levothyrox Sod_Oral Soln 25mcg/5ml S/F', 17),
#  ('Bonjela_Teething Gel', 19),
#  ('Salbutamol_Inh Soln 5mg/ml', 4),
#  ('Tinzaparin Sod_Inj 20 000u/ml 0.5ml Pfs', 18),
#  ('Advazorb 10cm x 10cm Wound Dress Polyure', 6),
#  ('ODM5 Sod Chlor Eye Dps 10ml P/F', 2),
#  ('Ciclosporin_Cap 25mg', 5),
#  ('Cefaclor_Cap 250mg', 2),
#  ('Balneum_Bath Oil 84.75%', 203),
#  ('Travoprost/Timolol_Eye Dps 40mcg/5mg', 390),
#  ('Methotrexate_Inj 10mg/0.2ml PF Dev', 23),
#  ('Millinette_Tab 30/75mcg', 84),
#  ('Durogesic DTrans_T/Derm Patch 75mcg', 23),
#  ('Zomig_Rapimelt Orodisper Tab 2.5mg', 3),
#  ('Fluticasone Prop_Crm 0.05%', 4),
#  ('Zafirlukast_Tab 20mg', 79),
#  ('Pizotifen Malate_Tab 500mcg', 1444),
#  ('Oilatum_Shower Gel Fragrance Free', 346),
#  ('Piroxicam_Cap 20mg', 4),
#  ('Convatec_Combihesive Natura Flx Flng 57m', 5),
#  ('Clearpore 10cm x 10cm VP Adh Film Dress', 2),
#  ('Brivaracetam_Tab 100mg', 2),
#  ('Fluticasone/Formoterol_Inh 250/10mcg120D', 198),
#  ('Rozex_Crm 0.75%', 22),
#  ('Drapolene_Crm', 27),
#  ('Prazosin HCl_Tab 500mcg', 7),
#  ('Sitagliptin_Tab 25mg', 355),
#  ('Oxcarbazepine_Tab 600mg', 16),
#  ('Mediven Elegance Class 1 Thigh + Top Ban', 2),
#  ('Gppe Pdr Sach_Dioralyte', 63),
#  ('Isomol Gel 100g', 18),
#  ('Synalar_Crm 0.025%', 12),
#  ('Activa Leg Ulcer Hose Kit Ex Exlge C/T C', 5),
#  ('Fluvastatin Sod_Cap 40mg', 57),
#  ('Melophthal 1% Carmellose Eye Dps 0.4ml U', 5),
#  ('Kolanticon_Gel S/F', 40),
#  ('Complan_Shake Pdr Sach 57g (Vanilla)', 131),
#  ('Keppra_Oral Soln 100mg/ml', 54),
#  ('K-Lite Long 10cm x 5.25m M/Layer Compres', 64),
#  ('Esomeprazole_Cap E/C 20mg', 688),
#  ('Zaluron XL_Tab 300mg', 227),
#  ('Tiopex_Gel Eye Dps 1mg/g 0.4g Ud', 70),
#  ('Durafiber Ag 2cm x 45cm Wound Dress Prot', 3),
#  ('GluNEO (Reagent)_Strips', 32),
#  ('Ciclesonide_Inh 160mcg (60 D) CFF', 32),
#  ('Nizatidine_Cap 150mg', 89),
#  ('Topamax_Tab 200mg', 4),
#  ('Sylk Vag Moist 40g Tube', 224),
#  ('Isoniazid_Tab 100mg', 16),
#  ('Anhydrol Fte_A-Pers Soln 20%', 17),
#  ('Colecal & Calc_Tab 400u/1.5g', 109),
#  ('Zispin_SolTab 45mg', 2),
#  ("Bullen_NA'Scent Odour Eliminator", 2),
#  ('Atarax_Tab 25mg', 24),
#  ('Lido HCl_Inj 2% 5ml Amp', 9),
#  ('Ponstan Fte_Tab 500mg', 6),
#  ('Estradot_Patch 25mcg/24hrs', 2),
#  ('Surg Suture W8020T Prolene Non-Absorb St', 50),
#  ('SMA_Lf Pdr', 94),
#  ('Diclomax SR_Cap 75mg', 4),
#  ('Bard Biocath Compreh/Care Foy Tray Male', 159),
#  ('Warfarin Sod_Oral Susp 1mg/1ml S/F', 2),
#  ('CliniSupplies_Prosys Cath Valve', 9),
#  ('Supralip 160_Tab 160mg', 24),
#  ('Innovace_Tab 20mg', 2),
#  ('Slo-Phyllin_Cap 125mg', 67),
#  ('Betaxolol_Susp Eye Dps 0.25% 0.25ml Udv', 8),
#  ('Olanzapine_Tab 20mg', 1111),
#  ('Salmeterol_Inha 25mcg (120 D) CFF', 1719),
#  ('Nutramigen 2 + LGG_Pdr', 107),
#  ('Lactic Acid/Salic Acid_Paint 16.7/16.7%', 178),
#  ('Hydrocort But_Scalp Lot 0.1%', 2),
#  ('Flupentixol Decan_Inj 20mg/ml 2ml Amp', 10),
#  ('Amlodipine/Valsartan_Tab 5mg/160mg', 2),
#  ('Glytrin_A/Spy 400mcg (200 D)', 6),
#  ('Alfacalcidol_Cap 250ng', 1777),
#  ('BD Micro-Fine Ultra Needles Pen Inj Scre', 1509),
#  ('Sumatriptan_Inj 6mg/0.5ml Pfs + Dev', 45),
#  ('Rabeprazole Sod_Tab E/C 20mg', 907),
#  ('Ipinnia XL_Tab 2mg', 4),
#  ('Morph Sulf_Tab 10mg', 172),
#  ('Tegretol Prolonged Release_Tab 400mg M/R', 1354),
#  ('B.Braun Actreen Fle Mini Nelaton 10-14 (', 5),
#  ('Hepat B_Vac 20mcg/ml 0.5ml Pfs', 2),
#  ('Convatec_Stomahesive Seal 48mm x 3mm', 4),
#  ('Fresubin Creme_Dessert (Cappuccino)', 2),
#  ('Eflornithine Monohyd Chlor_Crm 11.5%', 59),
#  ('Neocate Advance_Pdr Sach 50g (Flav)', 2),
#  ('Dansac_Night Drain Bag 2L', 3),
#  ('Indometacin_Cap 50mg', 252),
#  ('Elleste Duet_Tab 2mg', 129),
#  ('Ditropan_Tab 5mg', 37),
#  ('JLJ_Urifix Tape 5m', 16),
#  ('Dulaglutide_Inj 0.75mg/0.5ml Pf Dev', 2),
#  ('Voltarol Emulgel_Aq Gel 1.16%', 1099),
#  ('Aripiprazole_Inj 400mg Vl + Dil P/R', 2),
#  ('Mylife Clickfine AutoProtect Pen Inj Scr', 17),
#  ('Softpore 10cm x 10cm Pfa + Adh Border Dr', 121),
#  ('Jade_Ultra Flex Short Self-Adh Sheath Cl', 3),
#  ('Welland_Aura Flushable Clsd Pouch Midi B', 2),
#  ('Losec MUPS_Tab Disper 20mg (E/C Pellets)', 20),
#  ('Sod Fusidate_Oint 2%', 47),
#  ('Arcoxia_Tab 30mg', 4),
#  ('Anusol Plus HC_Oint', 23),
#  ('Valsartan/Hydchloroth_Tab 160mg/12.5mg', 99),
#  ('Provox Fltr HME Flexiderm Adh Oval 7254', 7),
#  ('Adalat Ret_Tab 10mg', 266),
#  ('Coloplast SpeediCath Compact Eve Fle 10-', 5),
#  ('Oxycodone HCl_Cap 10mg', 89),
#  ('Theophylline_Tab 200mg M/R', 72),
#  ('Indometacin_Cap 75mg M/R', 16),
#  ('Germoloids_Suppos', 4),
#  ('Oilatum_Emollient', 845),
#  ('Pelican_Select Drnbl Convex Pouch Clr Ma', 11),
#  ('Fluocinolone Aceton_Gel 0.025%', 21),
#  ('Alfuzosin HCl_Tab 2.5mg', 272),
#  ('Levomeprom HCl_Inj 25mg/ml 1ml Amp', 338),
#  ('Morph Sulf_Cap 30mg M/R', 285),
#  ('Fortisip Compact_Liq (8 Flav)', 1450),
#  ('Coloplast_SenSura Mio Click B/Plt L/Conv', 2),
#  ('Augmentin_Tab 375mg', 12),
#  ('Enalapril/Hydchloroth_Tab 20mg/12.5mg', 11),
#  ('Rizatriptan_Oral Lyophilisate Tab 10mg', 389),
#  ('Mebeverine HCl_Oral Susp 50mg/5ml S/F', 3),
#  ('CellCept_Tab 500mg', 11),
#  ('Promethazine HCl_Tab 10mg', 674),
#  ('Nasacort_Allergy Nsl Spy 55mcg (30D)', 3),
#  ('Nexplanon_Implant 68mg', 188),
#  ('Bicalutamide_Tab 150mg', 255),
#  ('Venlalic XL_Tab 225mg', 230),
#  ('Bicalutamide_Tab 50mg', 436),
#  ('Ferr Fumar_Cap 305mg', 1008),
#  ('Co-Beneldopa_Cap 25mg/100mg', 568),
#  ('Vital 1.5kcal_Liq (Vanilla)', 6),
#  ('Dermacolor_Camouflage Creme', 11),
#  ('Enopen Crm 500g', 16),
#  ('Cimetidine_Tab 400mg', 77),
#  ('Ingenol Mebutate_Gel 150mcg/g', 11),
#  ('Ethosuximide_Cap 250mg', 34),
#  ('Pelican_Release Non-Sting Adh Remover Sa', 2),
#  ('Nizoral_Shampoo 2%', 229),
#  ('Calcichew D3_Capl 500mg/400u', 367),
#  ('Stugeron_Tab 15mg', 7),
#  ('Hollister_Conform 2 + Lock/Roll Maxi Drn', 5),
#  ('BuTrans_Transdermal Patch 15mcg/hr', 25),
#  ('Zn Sulf Monohyd_Eff Tab 125mg', 25),
#  ('CliniMed_LiMone Deod A/Spy 50ml', 53),
#  ('Doxazosin Mesil_Tab 1mg', 3433),
#  ('Ins Humalog_100u/ml 3ml Cart', 712),
#  ('Genius_G/F Bread Wte Sandwich (Cut)', 8),
#  ('Mobile (Reagent)_Strips', 1871),
#  ('Fluticasone/Salmeterol_Inh 500/50mcg 60D', 2390),
#  ('Compact (Reagent)_Strips', 131),
#  ('Robaxin-750_Tab 750mg', 39),
#  ('Venaxx XL_Cap 75mg', 129),
#  ('Pentoxifylline_Tab 400mg M/R', 56),
#  ('Entacapone_Tab 200mg', 69),
#  ('Indivina_Tab 1mg/5mg', 3),
#  ('Colecal & Calc_Tab Chble 200u/1.25g', 396),
#  ('Daktarin Aktiv_Pdr Spy 0.16% 100g', 2),
#  ('Phenytoin_Sod Cap 100mg', 1569),
#  ('Valaciclovir_Tab 500mg', 17),
#  ('Ranitidine HCl_Oral Soln 75mg/5ml S/F', 880),
#  ('Omeprazole_Tab E/C 40mg', 84),
#  ('Dipyridamole_Tab 100mg', 79),
#  ('Promethazine Teoclate_Tab 25mg', 33),
#  ('Ins Aspart_Inj 100u/ml 10ml Vl', 5),
#  ('Zopiclone_Tab 3.75mg', 9369),
#  ('M.Sauer_NephSys Ster Drain Bag 500ml 20c', 2),
#  ('KerraPro 10 x 10 x 1.2cm Sheet Low Frict', 6),
#  ('Mediven For Men Class 2 B/Knee Closed To', 4),
#  ('Depo-Medrone/Lidoc_Inj 40/10mg/ml 1ml Vl', 251),
#  ('Conveen EasiCath Nelaton Fle Size 8-16 (', 6),
#  ('K-Plus Long 10cm x 10.25m M/Layer Compre', 7),
#  ('Pramipexole_Tab 88mcg', 971),
#  ('Dalteparin Sod_Inj 25 000u/ml 0.4ml Pfs', 15),
#  ('Bard Biocath H/Gel Foy Male 10ml Ball 12', 4),
#  ('Zoton_FasTab Tab 15mg', 53),
#  ('Aquacel Foam Adhesive 21cm x 21cm Wound', 3),
#  ('Comfifast 3.5cm x 1m (Red) Stkntte Elasc', 12),
#  ('Diclofenac Sod_Suppos 50mg', 8),
#  ('Dorzolamide_Eye Dps 2% 0.2ml Ud', 79),
#  ('Paracet_Oral Susp 250mg/5ml S/F', 3366),
#  ('Fluticasone Prop_Pdr For Inh 50mcg (60D)', 5),
#  ('GlucoLab (Reagent)_Strips', 679),
#  ('Estradiol_Gel 0.06% 80g (64 Applic)', 38),
#  ('Mylife Lancets 0.3mm/30 Gauge', 87),
#  ('Morph Sulf_Inj 10mg/1ml Amp', 428),
#  ('Sulfasalazine_Oral Susp 250mg/5ml S/F', 2),
#  ...]

# %%
max(items_by_bnf_name)
# Out:
# ('palmdoc (Reagent)_Strips', 6)

# %%
def criterion(tup):
    return tup[1]

# %%
max(items_by_bnf_name, key=lambda x:  x[1])
# Out:
# ('Omeprazole_Cap E/C 20mg', 113826)

# %%
max_item = [("Omeprazole_Cap  E/C 20mg", 113826)]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score: 0.000
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name',)` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data, fields):
    groups = {}
    for d in data:
        key = tuple(d[f])
    return groups

# %%
def sum_values(data, key):
    return sum([d[key] for d in data])

# %%
groups = group_by_field(scripts, ('bnf_name',))
test_max_item = ...

assert test_max_item == max_item
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-f139006cdbad> in <module>
# ----> 1 groups = group_by_field(scripts, ('bnf_name',))
#       2 test_max_item = ...
#       3
#       4 assert test_max_item == max_item
#
# <ipython-input-23-d6003f7aa915> in group_by_field(data, fields)
#       2     groups = {}
#       3     for d in data:
# ----> 4         key = tuple(d[f])
#       5     return groups
#
# KeyError: <gzip on 0x7ffa91354d30>

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    if practice['code'] in practice_postal:
        practice_postal[practice['code']] = min(practice['post_code'], practice_postal[practice['code']])
    else:
        practice_postal[practice['code']] = practice['post_code']

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:]
for script in joined:
    practice_code = script['practice']
    script['post_code'] = practice_postal[practice_code]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
grouped = group_by_field(joined, ('post_code',))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-ae5a2020a2ee> in <module>
# ----> 1 grouped = group_by_field(joined, ('post_code',))
#
# <ipython-input-23-d6003f7aa915> in group_by_field(data, fields)
#       2     groups = {}
#       3     for d in data:
# ----> 4         key = tuple(d[f])
#       5     return groups
#
# KeyError: <gzip on 0x7ffa91354d30>

# %%
postal_totals_all = [(post_code[0], sum_valuables(scripts_, 'items')) for post_code, scripts_ in grouped.items()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-60734fabd0fc> in <module>
# ----> 1 postal_totals_all = [(post_code[0], sum_valuables(scripts_, 'items')) for post_code, scripts_ in grouped.items()]
#
# NameError: name 'grouped' is not defined

# %%
[postal_totals = sorted(postal_totals_all)[:100]
# Out:
#   File "<ipython-input-33-a626b802d088>", line 1
#     [postal_totals = sorted(postal_totals_all)[:100]
#                    ^
# SyntaxError: invalid syntax

# %%
items_by_post = ...

# %%
postal_totals = [('B11 4BW', 20673)] * 100

grader.score.pw__postal_totals(postal_totals)
# Out:
# ==================
# Your score: 0.010
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.
#
# There are several approaches to solve this problem but we will guide you through one of them. Feel free to solve it your own way if it is easier for you to understand and implement. If your kernel keeps on dying, it's probably an indication that you are running out of memory. Consider deleting objects you don't need anymore using the `del` statement and shutdown any other running notebooks. For example:
# ```Python
# del some_object_not_needed
# ```

# %% [markdown]
# The first step is to calculate the total items for each `'post_code'` and `'bnf_name'`. Let's call that result `total_items_by_post_bnf`. Consider what is the best data structure(s) to represent `total_items_by_post_bnf`. It should have 141196 `('post_code', 'bnf_name')` groups.

# %%
grouped_by_post_bnf = ...

assert len(total_items_by_post_bnf) == 141196

# %% [markdown]
# Next, let's take `total_items_by_post_bnf` and group it by `'post_code'`. In other words, we want a  data structure that maps a `'post_code'` to a list of all records that belong to that `'post_code'`. There should be 118 groups.

# %%
grouped_post_code = ...

assert len(grouped_post_code) == 118

# %% [markdown]
# Now with `grouped_post_code`, let's iterate over each group and calculate the following fields for each `'post_code'`:
# 1. the sum of total items for all `'bnf_name'`
# 1. the most total items
# 1. the `'bnf_name'` that had the most total items
#
# Once again, consider the best data structure(s) to use to represent the result. It may help to write and use a function when developing your solution.

# %%
most_item_data_by_post = ...

# %% [markdown]
# Now, we are ready to:
# 1. calculate the ratio (the amount dispensed as proportion of total)
# 1. [sort](https://docs.python.org/3/howto/sorting.html) alphabetically by the post code
# 1. format the answer as a list of tuples
# 1. take only the first 100 tuples
# 1. submit to the grader

# %%
items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100

# %%
grader.score.pw__items_by_region(items_by_region)

# %% [markdown]
# *Copyright &copy; 2021 WorldQuant University. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
